# %%
import csv, re, random
import pandas as pd
from collections import Counter
from array import *

# %%
df_2010 = pd.read_pickle('df_2010.pkl')

# %%
df_2011 = pd.read_pickle('df_2011.pkl')

# %%
df_2012 = pd.read_pickle('df_2012.pkl')

# %%
df_2013 = pd.read_pickle('df_2013.pkl')

# %%
df_2014 = pd.read_pickle('df_2014.pkl')

# %%
df_2015 = pd.read_pickle('df_2015.pkl')

# %%
df_2016 = pd.read_pickle('df_2016.pkl')

# %%
df_2017 = pd.read_pickle('df_2017.pkl')

# %%
df_2018 = pd.read_pickle('df_2018.pkl')

# %%
df_2019 = pd.read_pickle('df_2019.pkl')

# %%
df_2020 = pd.read_pickle('df_2020.pkl')

# %%
df_2010
# Out:
#                                      txtfiles_au_2010  \
# 0   [2 metres , and we 're expecting that to conti...
# 1   [ <p> " Because of the side effects and becaus...
# 2   [ <p> Julie Dowse , the garden 's day service ...
# 3   [ The artist said that he knew of one young ma...
# 4   [ <p> New York Police Department spokesman Pau...
# 5   [ Who said size does n't matter ? When the sta...
# 6   [ <p> ' ' We 'd been hoping for a decision tha...
# 7   [ In 2017 he 'll start retiring his older 777s...
# 8   [ <p> " There is always this very marked visua...
# 9   [ <p> Fourteen of Mattel 's Fisher-Price produ...
# 10  [ But he said the principle of a fair go " doe...
# 11  [ " Not every sexual act has a reproductive fu...
#
#                                      txtfiles_bd_2010  \
# 0   [ <p> Hundreds of shoals have emerged in Surma...
# 1   [ We had slowed work mainly to bypass fallout ...
# 2   [ <p> Bangladeshi expatriates living in any fo...
# ...

# %%
# import gzip
# df_2016.to_pickle('df_2016.gzip', compression='gzip')

# %%
df_2010.txtfiles_au_2010[0]
# Out:
# ['2 metres , and we \'re expecting that to continue to increase in the short term , " he said .',
#  ' <p> " We \'re warning particularly campers at this time to move to higher ground and not to be camping alongside any river systems in the north-east of the state , as heavy rainfall is starting to see significant stream rises , " he said .',
#  ' <p> " There were some very heavy storms with falls of up to 60 millimetres around the Gisborne area , and also later on through Eildon , " he said .',
#  ' <p> " The lawyers that are in the know are actually clapping their hands because there \'s going to be more work for us , there \'s no doubt about that , " he said .',
#  ' <p> " If I \'m acting for the economically weaker spouse I \'ll say to them , well , look , if ca n\'t get a settlement that you like and you have to go to court about it , you might as well apply to set aside the agreement and let the full force of the Family Law Act work in your favour , " he said .',
# ...

# %%
# wordfreq = []
# counts_au_2010 = {}
# for article in df_2010.txtfiles_au_2010:
#     for quotes in article:
#         words = quotes.lower().split()
#         wordfreq.append(words)
# counts_au_2010 = Counter(x for sublist in wordfreq for x in sublist)

# %%
# counts_au_2010.most_common()

# %%
df_2010T = df_2010

# %%
df_2010P = pd.DataFrame()

# %%
df_2010P = df_2010P.reindex_like(df_2010T)

# %%
df_2010P
# Out:
#     txtfiles_au_2010  txtfiles_bd_2010  txtfiles_ca_2010  txtfiles_gb_2010  \
# 0                NaN               NaN               NaN               NaN
# 1                NaN               NaN               NaN               NaN
# 2                NaN               NaN               NaN               NaN
# 3                NaN               NaN               NaN               NaN
# 4                NaN               NaN               NaN               NaN
# 5                NaN               NaN               NaN               NaN
# 6                NaN               NaN               NaN               NaN
# 7                NaN               NaN               NaN               NaN
# 8                NaN               NaN               NaN               NaN
# 9                NaN               NaN               NaN               NaN
# 10               NaN               NaN               NaN               NaN
# ...

# %%
# items = []
# df_2010T.txtfiles_au_2010.replace('“','"')
# df_2010T.txtfiles_au_2010.replace('“','"')
    
# for article in df_2010T.txtfiles_au_2010:
#     for quote in article:
#         quo = re.findall('"([^"]*)"', quote)

# %%
# items = []

# for article in df_2010T.txtfiles_au_2010:
#     for quote in article:
#         quo = re.findall('"([^"]*)"', quote)
#         items.append(quo)

# %%
############## USE THIS ############
# items = []

# for article in df_2010T.txtfiles_au_2010[0]:
#     quo = re.findall('"([^"]*)"', article)
#     quo = [re.sub(r'\s+\'', "'", i) for i in quo]
#     items.extend(quo)

#######################################

# months = []

# for article in df_2010T.txtfiles_au_2010:
#     items = []
#     try:
#         for quotes in article:
#             quo = re.findall('"([^"]*)"', quotes)
#             quo = [re.sub(r'\s+\'', "'", i) for i in quo]
#             items.extend(quo)
#             items = list(filter(lambda x: x, items))
#             items = [item.lower() for item in items]
#             items = [item.replace("are n't", "aren't") for item in items]
#             items = [item.replace("ca n't", "can't") for item in items]
#             items = [item.replace("could n't", "couldn't") for item in items]
#             items = [item.replace("did n't", "didn't") for item in items]
#             items = [item.replace("does n't", "doesn't") for item in items]
#             items = [item.replace("do n't", "don't") for item in items]
#             items = [item.replace("had n't", "hadn't") for item in items]
#             items = [item.replace("has n't", "hasn't") for item in items]
#             items = [item.replace("have n't", "haven't") for item in items]
#             items = [item.replace("h e'd", "he'd") for item in items]
#             items = [item.replace("h e'll", "he'll") for item in items]
#             items = [item.replace("h e's", "he's") for item in items]
#             items = [item.replace("i 'd", "i'd") for item in items]
#             items = [item.replace("i 'll", "i'll") for item in items]    
#             items = [item.replace("i 'm", "i'm") for item in items]
#             items = [item.replace("i 've", "i've") for item in items]
#             items = [item.replace("is n't", "isn't") for item in items]
#             items = [item.replace("i t's", "it's") for item in items]
#             items = [item.replace("le t's", "let's") for item in items]
#             items = [item.replace("must n't", "mustn't") for item in items]
#             items = [item.replace("sha n't", "shan't") for item in items]
#             items = [item.replace("sh e'd", "she'd") for item in items]
#             items = [item.replace("sh e'll", "she'll") for item in items]
#             items = [item.replace("sh e's", "she's") for item in items]
#             items = [item.replace("should n't", "shouldn't") for item in items]
#             items = [item.replace("tha t's", "that's") for item in items]
#             items = [item.replace("ther e's", "there's") for item in items]
#             items = [item.replace("the y'll", "they'll") for item in items]
#             items = [item.replace("the y're", "they're") for item in items]
#             items = [item.replace("the y've", "they've") for item in items]
#             items = [item.replace("w e'd", "we'd") for item in items]
#             items = [item.replace("w e're", "we're") for item in items]
#             items = [item.replace("w e've", "we've") for item in items]
#             items = [item.replace("were n't", "weren't") for item in items]
#             items = [item.replace("wha t'll", "what'll") for item in items]
#             items = [item.replace("wha t're", "what're") for item in items]
#             items = [item.replace("wha t's", "what's") for item in items]
#             items = [item.replace("wha t've", "what've") for item in items]
#             items = [item.replace("wher e's", "where's") for item in items]
#             items = [item.replace("wh o'd", "who'd") for item in items]
#             items = [item.replace("wh o'll", "who'll") for item in items]
#             items = [item.replace("wh o're", "who're") for item in items]
#             items = [item.replace("wh o's", "who's") for item in items]
#             items = [item.replace("wh o've", "who've") for item in items]
#             items = [item.replace("wo n't", "won't") for item in items]
#             items = [item.replace("would n't", "wouldn't") for item in items]
#             items = [item.replace("yo u'd", "you'd") for item in items]
#             items = [item.replace("yo u'll", "you'll") for item in items]
#             items = [item.replace("yo u're", "you're") for item in items]
#             items = [item.replace("yo u've", "you've") for item in items]
#             items = [item.replace("<p>", "") for item in items]
#             items = [item.replace("<h>", "") for item in items]
#             items = [item.replace(" @ ", "") for item in items]
#             items = [item.replace("@", "") for item in items]
#             items = [item.replace("\n", "") for item in items]
#         months.append(items)
#     except:
#         months.append(items)
# df_2010P.txtfiles_au_2010 = months

# %%
months = []

for article in df_2010T.txtfiles_au_2010:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2010P.txtfiles_au_2010 = months

months = []

for article in df_2010T.txtfiles_bd_2010:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2010P.txtfiles_bd_2010 = months

months = []

for article in df_2010T.txtfiles_ca_2010:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2010P.txtfiles_ca_2010 = months

months = []

for article in df_2010T.txtfiles_gb_2010:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2010P.txtfiles_gb_2010 = months

months = []

for article in df_2010T.txtfiles_gh_2010:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2010P.txtfiles_gh_2010 = months

months = []

for article in df_2010T.txtfiles_hk_2010:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2010P.txtfiles_hk_2010 = months

months = []

for article in df_2010T.txtfiles_ie_2010:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2010P.txtfiles_ie_2010 = months

months = []

for article in df_2010T.txtfiles_in_2010:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2010P.txtfiles_in_2010 = months

months = []

for article in df_2010T.txtfiles_jm_2010:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2010P.txtfiles_jm_2010 = months

months = []

for article in df_2010T.txtfiles_ke_2010:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2010P.txtfiles_ke_2010 = months

months = []

for article in df_2010T.txtfiles_lk_2010:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2010P.txtfiles_lk_2010 = months

months = []

for article in df_2010T.txtfiles_my_2010:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2010P.txtfiles_my_2010 = months

months = []

for article in df_2010T.txtfiles_ng_2010:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2010P.txtfiles_ng_2010 = months

months = []

for article in df_2010T.txtfiles_nz_2010:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2010P.txtfiles_nz_2010 = months

months = []

for article in df_2010T.txtfiles_ph_2010:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2010P.txtfiles_ph_2010 = months

months = []

for article in df_2010T.txtfiles_pk_2010:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2010P.txtfiles_pk_2010 = months

months = []

for article in df_2010T.txtfiles_sg_2010:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2010P.txtfiles_sg_2010 = months

months = []

for article in df_2010T.txtfiles_tz_2010:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2010P.txtfiles_tz_2010 = months

months = []

for article in df_2010T.txtfiles_us_2010:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2010P.txtfiles_us_2010 = months

months = []

for article in df_2010T.txtfiles_za_2010:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2010P.txtfiles_za_2010 = months

# %%
df_2010P

# %%
df_2010P.to_pickle('df_2010P.pkl')

# %%
df_2011P = pd.DataFrame()
df_2011P = df_2011P.reindex_like(df_2011)

# %%
df_2011P
# Out:
#     txtfiles_au_2011  txtfiles_bd_2011  txtfiles_ca_2011  txtfiles_gb_2011  \
# 0                NaN               NaN               NaN               NaN
# 1                NaN               NaN               NaN               NaN
# 2                NaN               NaN               NaN               NaN
# 3                NaN               NaN               NaN               NaN
# 4                NaN               NaN               NaN               NaN
# 5                NaN               NaN               NaN               NaN
# 6                NaN               NaN               NaN               NaN
# 7                NaN               NaN               NaN               NaN
# 8                NaN               NaN               NaN               NaN
# 9                NaN               NaN               NaN               NaN
# 10               NaN               NaN               NaN               NaN
#
# ...

# %%
months = []

for article in df_2011T.txtfiles_au_2011:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2011P.txtfiles_au_2011 = months

months = []

for article in df_2011T.txtfiles_bd_2011:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2011P.txtfiles_bd_2011 = months

months = []

for article in df_2011T.txtfiles_ca_2011:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2011P.txtfiles_ca_2011 = months

months = []

for article in df_2011T.txtfiles_gb_2011:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2011P.txtfiles_gb_2011 = months

months = []

for article in df_2011T.txtfiles_gh_2011:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2011P.txtfiles_gh_2011 = months

months = []

for article in df_2011T.txtfiles_hk_2011:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2011P.txtfiles_hk_2011 = months

months = []

for article in df_2011T.txtfiles_ie_2011:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2011P.txtfiles_ie_2011 = months

months = []

for article in df_2011T.txtfiles_in_2011:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2011P.txtfiles_in_2011 = months

months = []

for article in df_2011T.txtfiles_jm_2011:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2011P.txtfiles_jm_2011 = months

months = []

for article in df_2011T.txtfiles_ke_2011:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2011P.txtfiles_ke_2011 = months

months = []

for article in df_2011T.txtfiles_lk_2011:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2011P.txtfiles_lk_2011 = months

months = []

for article in df_2011T.txtfiles_my_2011:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2011P.txtfiles_my_2011 = months

months = []

for article in df_2011T.txtfiles_ng_2011:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2011P.txtfiles_ng_2011 = months

months = []

for article in df_2011T.txtfiles_nz_2011:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2011P.txtfiles_nz_2011 = months

months = []

for article in df_2011T.txtfiles_ph_2011:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2011P.txtfiles_ph_2011 = months

months = []

for article in df_2011T.txtfiles_pk_2011:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2011P.txtfiles_pk_2011 = months

months = []

for article in df_2011T.txtfiles_sg_2011:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2011P.txtfiles_sg_2011 = months

months = []

for article in df_2011T.txtfiles_tz_2011:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2011P.txtfiles_tz_2011 = months

months = []

for article in df_2011T.txtfiles_us_2011:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2011P.txtfiles_us_2011 = months

months = []

for article in df_2011T.txtfiles_za_2011:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2011P.txtfiles_za_2011 = months

# %%
df_2011P
# Out:
#                                      txtfiles_au_2011  \
# 0   [ there are many layouts that are designated p...
# 1   [ they caught me , ,  i fell down and the secu...
# 2   [  she also said she would continue to explore...
# 3   [ the gallery will feature artworks from arhne...
# 4   [ my absolute economic development strategy is...
# 5   [ in the younger group we think this is occurr...
# 6   [ it was very interesting to discover that he ...
# 7   [ we got a saving of about 70 litres per perso...
# 8   [ free mumtaz qadri ,  we are ready to sacrifi...
# 9   [ all we're after is a fair and reasonable out...
# 10  [ over the past few years , deck-building game...
#
#                                      txtfiles_bd_2011  \
# 0   [  regarding lawyers , he said : ,  if we want...
# 1   [ arati ( special prayer ) will take place at ...
# 2   [ after killing bangabandhu on august 15 , 197...
# 3   [ i am now worried whether i can maintain the ...
# ...

# %%
df_2011P.to_pickle('df_2011P.pkl')

# %%
df_2012P = pd.DataFrame()
df_2012P = df_2012P.reindex_like(df_2012)

# %%
months = []

for article in df_2012T.txtfiles_au_2012:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2012P.txtfiles_au_2012 = months

months = []

for article in df_2012T.txtfiles_bd_2012:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2012P.txtfiles_bd_2012 = months

months = []

for article in df_2012T.txtfiles_ca_2012:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2012P.txtfiles_ca_2012 = months

months = []

for article in df_2012T.txtfiles_gb_2012:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2012P.txtfiles_gb_2012 = months

months = []

for article in df_2012T.txtfiles_gh_2012:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2012P.txtfiles_gh_2012 = months

months = []

for article in df_2012T.txtfiles_hk_2012:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2012P.txtfiles_hk_2012 = months

months = []

for article in df_2012T.txtfiles_ie_2012:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2012P.txtfiles_ie_2012 = months

months = []

for article in df_2012T.txtfiles_in_2012:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2012P.txtfiles_in_2012 = months

months = []

for article in df_2012T.txtfiles_jm_2012:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2012P.txtfiles_jm_2012 = months

months = []

for article in df_2012T.txtfiles_ke_2012:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2012P.txtfiles_ke_2012 = months

months = []

for article in df_2012T.txtfiles_lk_2012:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2012P.txtfiles_lk_2012 = months

months = []

for article in df_2012T.txtfiles_my_2012:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2012P.txtfiles_my_2012 = months

months = []

for article in df_2012T.txtfiles_ng_2012:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2012P.txtfiles_ng_2012 = months

months = []

for article in df_2012T.txtfiles_nz_2012:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2012P.txtfiles_nz_2012 = months

months = []

for article in df_2012T.txtfiles_ph_2012:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2012P.txtfiles_ph_2012 = months

months = []

for article in df_2012T.txtfiles_pk_2012:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2012P.txtfiles_pk_2012 = months

months = []

for article in df_2012T.txtfiles_sg_2012:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2012P.txtfiles_sg_2012 = months

months = []

for article in df_2012T.txtfiles_tz_2012:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2012P.txtfiles_tz_2012 = months

months = []

for article in df_2012T.txtfiles_us_2012:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2012P.txtfiles_us_2012 = months

months = []

for article in df_2012T.txtfiles_za_2012:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2012P.txtfiles_za_2012 = months

# %%
df_2012P

# %%
df_2012P.to_pickle('df_2012P.pkl')

# %%
df_2013P = pd.DataFrame()
df_2013P = df_2013P.reindex_like(df_2013)

# %%
df_2014P = pd.DataFrame()
df_2014P = df_2014P.reindex_like(df_2014)

# %%
df_2015P = pd.DataFrame()
df_2015P = df_2015P.reindex_like(df_2015)

# %%
df_2016P = pd.DataFrame()
df_2016P = df_2016P.reindex_like(df_2016)

# %%
df_2017P = pd.DataFrame()
df_2017P = df_2017P.reindex_like(df_2017)

# %%
df_2018P = pd.DataFrame()
df_2018P = df_2018P.reindex_like(df_2018)

# %%
df_2019P = pd.DataFrame()
df_2019P = df_2019P.reindex_like(df_2019)

# %%
df_2020P = pd.DataFrame()
df_2020P = df_2020P.reindex_like(df_2020)

# %%
months = []

for article in df_2013T.txtfiles_au_2013:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2013P.txtfiles_au_2013 = months

months = []

for article in df_2013T.txtfiles_bd_2013:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2013P.txtfiles_bd_2013 = months

months = []

for article in df_2013T.txtfiles_ca_2013:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2013P.txtfiles_ca_2013 = months

months = []

for article in df_2013T.txtfiles_gb_2013:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2013P.txtfiles_gb_2013 = months

months = []

for article in df_2013T.txtfiles_gh_2013:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2013P.txtfiles_gh_2013 = months

months = []

for article in df_2013T.txtfiles_hk_2013:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2013P.txtfiles_hk_2013 = months

months = []

for article in df_2013T.txtfiles_ie_2013:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2013P.txtfiles_ie_2013 = months

months = []

for article in df_2013T.txtfiles_in_2013:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2013P.txtfiles_in_2013 = months

months = []

for article in df_2013T.txtfiles_jm_2013:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2013P.txtfiles_jm_2013 = months

months = []

for article in df_2013T.txtfiles_ke_2013:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2013P.txtfiles_ke_2013 = months

months = []

for article in df_2013T.txtfiles_lk_2013:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2013P.txtfiles_lk_2013 = months

months = []

for article in df_2013T.txtfiles_my_2013:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2013P.txtfiles_my_2013 = months

months = []

for article in df_2013T.txtfiles_ng_2013:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2013P.txtfiles_ng_2013 = months

months = []

for article in df_2013T.txtfiles_nz_2013:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2013P.txtfiles_nz_2013 = months

months = []

for article in df_2013T.txtfiles_ph_2013:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2013P.txtfiles_ph_2013 = months

months = []

for article in df_2013T.txtfiles_pk_2013:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2013P.txtfiles_pk_2013 = months

months = []

for article in df_2013T.txtfiles_sg_2013:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2013P.txtfiles_sg_2013 = months

months = []

for article in df_2013T.txtfiles_tz_2013:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2013P.txtfiles_tz_2013 = months

months = []

for article in df_2013T.txtfiles_us_2013:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2013P.txtfiles_us_2013 = months

months = []

for article in df_2013T.txtfiles_za_2013:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2013P.txtfiles_za_2013 = months

# %%
df_2013P

# %%
df_2013P.to_pickle('df_2013P.pkl')

# %%
months = []

for article in df_2014T.txtfiles_au_2014:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2014P.txtfiles_au_2014 = months

months = []

for article in df_2014T.txtfiles_bd_2014:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2014P.txtfiles_bd_2014 = months

months = []

for article in df_2014T.txtfiles_ca_2014:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2014P.txtfiles_ca_2014 = months

months = []

for article in df_2014T.txtfiles_gb_2014:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2014P.txtfiles_gb_2014 = months

months = []

for article in df_2014T.txtfiles_gh_2014:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2014P.txtfiles_gh_2014 = months

months = []

for article in df_2014T.txtfiles_hk_2014:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2014P.txtfiles_hk_2014 = months

months = []

for article in df_2014T.txtfiles_ie_2014:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2014P.txtfiles_ie_2014 = months

months = []

for article in df_2014T.txtfiles_in_2014:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2014P.txtfiles_in_2014 = months

months = []

for article in df_2014T.txtfiles_jm_2014:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2014P.txtfiles_jm_2014 = months

months = []

for article in df_2014T.txtfiles_ke_2014:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2014P.txtfiles_ke_2014 = months

months = []

for article in df_2014T.txtfiles_lk_2014:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2014P.txtfiles_lk_2014 = months

months = []

for article in df_2014T.txtfiles_my_2014:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2014P.txtfiles_my_2014 = months

months = []

for article in df_2014T.txtfiles_ng_2014:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2014P.txtfiles_ng_2014 = months

months = []

for article in df_2014T.txtfiles_nz_2014:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2014P.txtfiles_nz_2014 = months

months = []

for article in df_2014T.txtfiles_ph_2014:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2014P.txtfiles_ph_2014 = months

months = []

for article in df_2014T.txtfiles_pk_2014:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2014P.txtfiles_pk_2014 = months

months = []

for article in df_2014T.txtfiles_sg_2014:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2014P.txtfiles_sg_2014 = months

months = []

for article in df_2014T.txtfiles_tz_2014:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2014P.txtfiles_tz_2014 = months

months = []

for article in df_2014T.txtfiles_us_2014:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2014P.txtfiles_us_2014 = months

months = []

for article in df_2014T.txtfiles_za_2014:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2014P.txtfiles_za_2014 = months

# %%
df_2014P

# %%
df_2014P.to_pickle('df_2014P.pkl')

# %%
months = []

for article in df_2015T.txtfiles_au_2015:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2015P.txtfiles_au_2015 = months

months = []

for article in df_2015T.txtfiles_bd_2015:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2015P.txtfiles_bd_2015 = months

months = []

for article in df_2015T.txtfiles_ca_2015:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2015P.txtfiles_ca_2015 = months

months = []

for article in df_2015T.txtfiles_gb_2015:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2015P.txtfiles_gb_2015 = months

months = []

for article in df_2015T.txtfiles_gh_2015:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2015P.txtfiles_gh_2015 = months

months = []

for article in df_2015T.txtfiles_hk_2015:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2015P.txtfiles_hk_2015 = months

months = []

for article in df_2015T.txtfiles_ie_2015:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2015P.txtfiles_ie_2015 = months

months = []

for article in df_2015T.txtfiles_in_2015:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2015P.txtfiles_in_2015 = months

months = []

for article in df_2015T.txtfiles_jm_2015:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2015P.txtfiles_jm_2015 = months

months = []

for article in df_2015T.txtfiles_ke_2015:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2015P.txtfiles_ke_2015 = months

months = []

for article in df_2015T.txtfiles_lk_2015:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2015P.txtfiles_lk_2015 = months

months = []

for article in df_2015T.txtfiles_my_2015:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2015P.txtfiles_my_2015 = months

months = []

for article in df_2015T.txtfiles_ng_2015:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2015P.txtfiles_ng_2015 = months

months = []

for article in df_2015T.txtfiles_nz_2015:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2015P.txtfiles_nz_2015 = months

months = []

for article in df_2015T.txtfiles_ph_2015:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2015P.txtfiles_ph_2015 = months

months = []

for article in df_2015T.txtfiles_pk_2015:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2015P.txtfiles_pk_2015 = months

months = []

for article in df_2015T.txtfiles_sg_2015:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2015P.txtfiles_sg_2015 = months

months = []

for article in df_2015T.txtfiles_tz_2015:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2015P.txtfiles_tz_2015 = months

months = []

for article in df_2015T.txtfiles_us_2015:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2015P.txtfiles_us_2015 = months

months = []

for article in df_2015T.txtfiles_za_2015:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2015P.txtfiles_za_2015 = months

# %%
df_2015P

# %%
df_2015P.to_pickle('df_2015P.pkl')

# %%
months = []

for article in df_2016T.txtfiles_au_2016:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2016P.txtfiles_au_2016 = months

months = []

for article in df_2016T.txtfiles_bd_2016:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2016P.txtfiles_bd_2016 = months

months = []

for article in df_2016T.txtfiles_ca_2016:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2016P.txtfiles_ca_2016 = months

months = []

for article in df_2016T.txtfiles_gb_2016:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2016P.txtfiles_gb_2016 = months

months = []

for article in df_2016T.txtfiles_gh_2016:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2016P.txtfiles_gh_2016 = months

months = []

for article in df_2016T.txtfiles_hk_2016:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2016P.txtfiles_hk_2016 = months

months = []

for article in df_2016T.txtfiles_ie_2016:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2016P.txtfiles_ie_2016 = months

months = []

for article in df_2016T.txtfiles_in_2016:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2016P.txtfiles_in_2016 = months

months = []

for article in df_2016T.txtfiles_jm_2016:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2016P.txtfiles_jm_2016 = months

months = []

for article in df_2016T.txtfiles_ke_2016:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2016P.txtfiles_ke_2016 = months

months = []

for article in df_2016T.txtfiles_lk_2016:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2016P.txtfiles_lk_2016 = months

months = []

for article in df_2016T.txtfiles_my_2016:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2016P.txtfiles_my_2016 = months

months = []

for article in df_2016T.txtfiles_ng_2016:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2016P.txtfiles_ng_2016 = months

months = []

for article in df_2016T.txtfiles_nz_2016:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2016P.txtfiles_nz_2016 = months

months = []

for article in df_2016T.txtfiles_ph_2016:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2016P.txtfiles_ph_2016 = months

months = []

for article in df_2016T.txtfiles_pk_2016:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2016P.txtfiles_pk_2016 = months

months = []

for article in df_2016T.txtfiles_sg_2016:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2016P.txtfiles_sg_2016 = months

months = []

for article in df_2016T.txtfiles_tz_2016:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2016P.txtfiles_tz_2016 = months

months = []

for article in df_2016T.txtfiles_us_2016:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2016P.txtfiles_us_2016 = months

months = []

for article in df_2016T.txtfiles_za_2016:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2016P.txtfiles_za_2016 = months

# %%
df_2016P

# %%
df_2016P.to_pickle('df_2016P.pkl')

# %%
months = []

for article in df_2017T.txtfiles_au_2017:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2017P.txtfiles_au_2017 = months

months = []

for article in df_2017T.txtfiles_bd_2017:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2017P.txtfiles_bd_2017 = months

months = []

for article in df_2017T.txtfiles_ca_2017:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2017P.txtfiles_ca_2017 = months

months = []

for article in df_2017T.txtfiles_gb_2017:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2017P.txtfiles_gb_2017 = months

months = []

for article in df_2017T.txtfiles_gh_2017:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2017P.txtfiles_gh_2017 = months

months = []

for article in df_2017T.txtfiles_hk_2017:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2017P.txtfiles_hk_2017 = months

months = []

for article in df_2017T.txtfiles_ie_2017:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2017P.txtfiles_ie_2017 = months

months = []

for article in df_2017T.txtfiles_in_2017:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2017P.txtfiles_in_2017 = months

months = []

for article in df_2017T.txtfiles_jm_2017:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2017P.txtfiles_jm_2017 = months

months = []

for article in df_2017T.txtfiles_ke_2017:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2017P.txtfiles_ke_2017 = months

months = []

for article in df_2017T.txtfiles_lk_2017:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2017P.txtfiles_lk_2017 = months

months = []

for article in df_2017T.txtfiles_my_2017:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2017P.txtfiles_my_2017 = months

months = []

for article in df_2017T.txtfiles_ng_2017:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2017P.txtfiles_ng_2017 = months

months = []

for article in df_2017T.txtfiles_nz_2017:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2017P.txtfiles_nz_2017 = months

months = []

for article in df_2017T.txtfiles_ph_2017:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2017P.txtfiles_ph_2017 = months

months = []

for article in df_2017T.txtfiles_pk_2017:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2017P.txtfiles_pk_2017 = months

months = []

for article in df_2017T.txtfiles_sg_2017:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2017P.txtfiles_sg_2017 = months

months = []

for article in df_2017T.txtfiles_tz_2017:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2017P.txtfiles_tz_2017 = months

months = []

for article in df_2017T.txtfiles_us_2017:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2017P.txtfiles_us_2017 = months

months = []

for article in df_2017T.txtfiles_za_2017:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2017P.txtfiles_za_2017 = months

# %%
df_2017P

# %%
df_2017P.to_pickle('df_2017P.pkl')

# %%
months = []

for article in df_2018T.txtfiles_au_2018:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2018P.txtfiles_au_2018 = months

months = []

for article in df_2018T.txtfiles_bd_2018:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2018P.txtfiles_bd_2018 = months

months = []

for article in df_2018T.txtfiles_ca_2018:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2018P.txtfiles_ca_2018 = months

months = []

for article in df_2018T.txtfiles_gb_2018:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2018P.txtfiles_gb_2018 = months

months = []

for article in df_2018T.txtfiles_gh_2018:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2018P.txtfiles_gh_2018 = months

months = []

for article in df_2018T.txtfiles_hk_2018:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2018P.txtfiles_hk_2018 = months

months = []

for article in df_2018T.txtfiles_ie_2018:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2018P.txtfiles_ie_2018 = months

months = []

for article in df_2018T.txtfiles_in_2018:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2018P.txtfiles_in_2018 = months

months = []

for article in df_2018T.txtfiles_jm_2018:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2018P.txtfiles_jm_2018 = months

months = []

for article in df_2018T.txtfiles_ke_2018:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2018P.txtfiles_ke_2018 = months

months = []

for article in df_2018T.txtfiles_lk_2018:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2018P.txtfiles_lk_2018 = months

months = []

for article in df_2018T.txtfiles_my_2018:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2018P.txtfiles_my_2018 = months

months = []

for article in df_2018T.txtfiles_ng_2018:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2018P.txtfiles_ng_2018 = months

months = []

for article in df_2018T.txtfiles_nz_2018:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2018P.txtfiles_nz_2018 = months

months = []

for article in df_2018T.txtfiles_ph_2018:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2018P.txtfiles_ph_2018 = months

months = []

for article in df_2018T.txtfiles_pk_2018:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2018P.txtfiles_pk_2018 = months

months = []

for article in df_2018T.txtfiles_sg_2018:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2018P.txtfiles_sg_2018 = months

months = []

for article in df_2018T.txtfiles_tz_2018:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2018P.txtfiles_tz_2018 = months

months = []

for article in df_2018T.txtfiles_us_2018:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2018P.txtfiles_us_2018 = months

months = []

for article in df_2018T.txtfiles_za_2018:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2018P.txtfiles_za_2018 = months

# %%
df_2018P

# %%
df_2018P.to_pickle('df_2018P.pkl')

# %%
months = []

for article in df_2019T.txtfiles_au_2019:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2019P.txtfiles_au_2019 = months

months = []

for article in df_2019T.txtfiles_bd_2019:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2019P.txtfiles_bd_2019 = months

months = []

for article in df_2019T.txtfiles_ca_2019:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2019P.txtfiles_ca_2019 = months

months = []

for article in df_2019T.txtfiles_gb_2019:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2019P.txtfiles_gb_2019 = months

months = []

for article in df_2019T.txtfiles_gh_2019:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2019P.txtfiles_gh_2019 = months

months = []

for article in df_2019T.txtfiles_hk_2019:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2019P.txtfiles_hk_2019 = months

months = []

for article in df_2019T.txtfiles_ie_2019:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2019P.txtfiles_ie_2019 = months

months = []

for article in df_2019T.txtfiles_in_2019:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2019P.txtfiles_in_2019 = months

months = []

for article in df_2019T.txtfiles_jm_2019:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2019P.txtfiles_jm_2019 = months

months = []

for article in df_2019T.txtfiles_ke_2019:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2019P.txtfiles_ke_2019 = months

months = []

for article in df_2019T.txtfiles_lk_2019:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2019P.txtfiles_lk_2019 = months

months = []

for article in df_2019T.txtfiles_my_2019:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2019P.txtfiles_my_2019 = months

months = []

for article in df_2019T.txtfiles_ng_2019:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2019P.txtfiles_ng_2019 = months

months = []

for article in df_2019T.txtfiles_nz_2019:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2019P.txtfiles_nz_2019 = months

months = []

for article in df_2019T.txtfiles_ph_2019:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2019P.txtfiles_ph_2019 = months

months = []

for article in df_2019T.txtfiles_pk_2019:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2019P.txtfiles_pk_2019 = months

months = []

for article in df_2019T.txtfiles_sg_2019:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2019P.txtfiles_sg_2019 = months

months = []

for article in df_2019T.txtfiles_tz_2019:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2019P.txtfiles_tz_2019 = months

months = []

for article in df_2019T.txtfiles_us_2019:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2019P.txtfiles_us_2019 = months

months = []

for article in df_2019T.txtfiles_za_2019:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2019P.txtfiles_za_2019 = months

# %%
df_2019P

# %%
df_2019P.to_pickle('df_2019P.pkl')

# %%
months = []

for article in df_2020T.txtfiles_au_2020:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2020P.txtfiles_au_2020 = months

months = []

for article in df_2020T.txtfiles_bd_2020:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2020P.txtfiles_bd_2020 = months

months = []

for article in df_2020T.txtfiles_ca_2020:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2020P.txtfiles_ca_2020 = months

months = []

for article in df_2020T.txtfiles_gb_2020:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2020P.txtfiles_gb_2020 = months

months = []

for article in df_2020T.txtfiles_gh_2020:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2020P.txtfiles_gh_2020 = months

months = []

for article in df_2020T.txtfiles_hk_2020:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2020P.txtfiles_hk_2020 = months

months = []

for article in df_2020T.txtfiles_ie_2020:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2020P.txtfiles_ie_2020 = months

months = []

for article in df_2020T.txtfiles_in_2020:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2020P.txtfiles_in_2020 = months

months = []

for article in df_2020T.txtfiles_jm_2020:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2020P.txtfiles_jm_2020 = months

months = []

for article in df_2020T.txtfiles_ke_2020:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2020P.txtfiles_ke_2020 = months

months = []

for article in df_2020T.txtfiles_lk_2020:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2020P.txtfiles_lk_2020 = months

months = []

for article in df_2020T.txtfiles_my_2020:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2020P.txtfiles_my_2020 = months

months = []

for article in df_2020T.txtfiles_ng_2020:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2020P.txtfiles_ng_2020 = months

months = []

for article in df_2020T.txtfiles_nz_2020:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2020P.txtfiles_nz_2020 = months

months = []

for article in df_2020T.txtfiles_ph_2020:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2020P.txtfiles_ph_2020 = months

months = []

for article in df_2020T.txtfiles_pk_2020:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2020P.txtfiles_pk_2020 = months

months = []

for article in df_2020T.txtfiles_sg_2020:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2020P.txtfiles_sg_2020 = months

months = []

for article in df_2020T.txtfiles_tz_2020:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2020P.txtfiles_tz_2020 = months

months = []

for article in df_2020T.txtfiles_us_2020:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2020P.txtfiles_us_2020 = months

months = []

for article in df_2020T.txtfiles_za_2020:
    items = []
    try:
        for quotes in article:
            quo = re.findall('"([^"]*)"', quotes)
            quo = [re.sub(r'\s+\'', "'", i) for i in quo]
            items.extend(quo)
            items = list(filter(lambda x: x, items))
            items = [item.lower() for item in items]
            items = [item.replace("are n't", "aren't") for item in items]
            items = [item.replace("ca n't", "can't") for item in items]
            items = [item.replace("could n't", "couldn't") for item in items]
            items = [item.replace("did n't", "didn't") for item in items]
            items = [item.replace("does n't", "doesn't") for item in items]
            items = [item.replace("do n't", "don't") for item in items]
            items = [item.replace("had n't", "hadn't") for item in items]
            items = [item.replace("has n't", "hasn't") for item in items]
            items = [item.replace("have n't", "haven't") for item in items]
            items = [item.replace("h e'd", "he'd") for item in items]
            items = [item.replace("h e'll", "he'll") for item in items]
            items = [item.replace("h e's", "he's") for item in items]
            items = [item.replace("i 'd", "i'd") for item in items]
            items = [item.replace("i 'll", "i'll") for item in items]    
            items = [item.replace("i 'm", "i'm") for item in items]
            items = [item.replace("i 've", "i've") for item in items]
            items = [item.replace("is n't", "isn't") for item in items]
            items = [item.replace("i t's", "it's") for item in items]
            items = [item.replace("le t's", "let's") for item in items]
            items = [item.replace("must n't", "mustn't") for item in items]
            items = [item.replace("sha n't", "shan't") for item in items]
            items = [item.replace("sh e'd", "she'd") for item in items]
            items = [item.replace("sh e'll", "she'll") for item in items]
            items = [item.replace("sh e's", "she's") for item in items]
            items = [item.replace("should n't", "shouldn't") for item in items]
            items = [item.replace("tha t's", "that's") for item in items]
            items = [item.replace("ther e's", "there's") for item in items]
            items = [item.replace("the y'll", "they'll") for item in items]
            items = [item.replace("the y're", "they're") for item in items]
            items = [item.replace("the y've", "they've") for item in items]
            items = [item.replace("w e'd", "we'd") for item in items]
            items = [item.replace("w e're", "we're") for item in items]
            items = [item.replace("w e've", "we've") for item in items]
            items = [item.replace("were n't", "weren't") for item in items]
            items = [item.replace("wha t'll", "what'll") for item in items]
            items = [item.replace("wha t're", "what're") for item in items]
            items = [item.replace("wha t's", "what's") for item in items]
            items = [item.replace("wha t've", "what've") for item in items]
            items = [item.replace("wher e's", "where's") for item in items]
            items = [item.replace("wh o'd", "who'd") for item in items]
            items = [item.replace("wh o'll", "who'll") for item in items]
            items = [item.replace("wh o're", "who're") for item in items]
            items = [item.replace("wh o's", "who's") for item in items]
            items = [item.replace("wh o've", "who've") for item in items]
            items = [item.replace("wo n't", "won't") for item in items]
            items = [item.replace("would n't", "wouldn't") for item in items]
            items = [item.replace("yo u'd", "you'd") for item in items]
            items = [item.replace("yo u'll", "you'll") for item in items]
            items = [item.replace("yo u're", "you're") for item in items]
            items = [item.replace("yo u've", "you've") for item in items]
            items = [item.replace("<p>", "") for item in items]
            items = [item.replace("<h>", "") for item in items]
            items = [item.replace(" @ ", "") for item in items]
            items = [item.replace("@", "") for item in items]
            items = [item.replace("\n", "") for item in items]
        months.append(items)
    except:
        months.append(items)
df_2020P.txtfiles_za_2020 = months

# %%
df_2020P

# %%
df_2020P.to_pickle('df_2020P.pkl')
